# %%
import os
import lightning.pytorch as pl

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
import torchmetrics
import wandb
from lightning.pytorch.loggers import WandbLogger

# %%
PATH_DATASETS = os.environ.get("PATH_DATASETS","/users/PLS0129/ysu0053/CSCI4852_6852_F23_DL/data")
BATCH_SIZE = 256 if torch.cuda.is_available() else 64

# %%
# setting device on GPU if available, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print('Number of GPUs:',torch.cuda.device_count())
print()

#Additional Info when using cuda
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
# Out:
# Using device: cuda
# Number of GPUs: 1
#
# Tesla V100-PCIE-16GB
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
# Define the Lightning module
class MNISTLightning(pl.LightningModule):
    def __init__(self, data_dir=PATH_DATASETS, hidden_size=64, learning_rate=2e-4):
        super().__init__()

        # Set our init args as class attributes
        self.data_dir = data_dir
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate

        # Hardcode some dataset specific attributes
        self.num_classes = 10
        self.dims = (1, 28, 28)
        channels, width, height = self.dims
        self.transform = transforms.Compose(
            [
                transforms.ToTensor(),
                transforms.Normalize((0.1307,), (0.3081,)),
            ]
        )

        # Define PyTorch model
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(channels * width * height, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size, self.num_classes),
        )

        self.val_accuracy = torchmetrics.classification.Accuracy(task="multiclass", num_classes=10)
        self.test_accuracy = torchmetrics.classification.Accuracy(task="multiclass", num_classes=10)

    def forward(self, x):
        x = self.model(x)
        return F.log_softmax(x, dim=1)

    def training_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = F.nll_loss(logits, y)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = F.nll_loss(logits, y)
        preds = torch.argmax(logits, dim=1)
        self.val_accuracy.update(preds, y)

        # Calling self.log will surface up scalars for you in TensorBoard
        self.log("val_loss", loss, prog_bar=True)
        self.log("val_acc", self.val_accuracy, prog_bar=True)

    def test_step(self, batch, batch_idx):
        x, y = batch
        logits = self(x)
        loss = F.nll_loss(logits, y)
        preds = torch.argmax(logits, dim=1)
        self.test_accuracy.update(preds, y)

        # Calling self.log will surface up scalars for you in TensorBoard
        self.log("test_loss", loss, prog_bar=True)
        self.log("test_acc", self.test_accuracy, prog_bar=True)

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate)
        return optimizer

    ####################
    # DATA RELATED HOOKS
    ####################

    def prepare_data(self):
        # download
        datasets.MNIST(self.data_dir, train=True, download=True)
        datasets.MNIST(self.data_dir, train=False, download=True)

    def setup(self, stage=None):
        # Assign train/val datasets for use in dataloaders
        if stage == "fit" or stage is None:
            mnist_full = datasets.MNIST(self.data_dir, train=True, transform=self.transform)
            self.mnist_train, self.mnist_val = random_split(mnist_full, [50000, 10000])

        # Assign test dataset for use in dataloader(s)
        if stage == "test" or stage is None:
            self.mnist_test = datasets.MNIST(self.data_dir, train=False, transform=self.transform)

    def train_dataloader(self):
        return DataLoader(self.mnist_train, batch_size=BATCH_SIZE)

    def val_dataloader(self):
        return DataLoader(self.mnist_val, batch_size=BATCH_SIZE)

    def test_dataloader(self):
        return DataLoader(self.mnist_test, batch_size=BATCH_SIZE)

# %%
# Init our model
mnist_model = MNISTLightning()

# Initialize wandb
wandb.init(project='mnist_mlp')
settings=wandb.Settings(silent="True")

# Create the WandbLogger
wandb_logger = WandbLogger()

# Initialize a trainer
trainer = pl.Trainer(accelerator="auto",devices=1,max_epochs=15, logger=wandb_logger) 
# Train the model ⚡
trainer.fit(mnist_model)

#Testing
trainer.test()
# Close wandb run
wandb.finish()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: alazar. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.10
# Run data is saved locally in <code>/users/PLS0129/ysu0053/CSCI4852_6852_F23_DL/lab3/wandb/run-20230910_185110-ekf96407</code>
# Syncing run <strong><a href='https://wandb.ai/alazar/mnist_mlp_3/runs/ekf96407' target="_blank">jumping-surf-4</a></strong> to <a href='https://wandb.ai/alazar/mnist_mlp_3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alazar/mnist_mlp_3' target="_blank">https://wandb.ai/alazar/mnist_mlp_3</a>
#  View run at <a href='https://wandb.ai/alazar/mnist_mlp_3/runs/ekf96407' target="_blank">https://wandb.ai/alazar/mnist_mlp_3/runs/ekf96407</a>
# /users/PLS0129/ysu0053/.conda/envs/torch/lib/python3.10/site-packages/lightning/pytorch/loggers/wandb.py:398: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#   rank_zero_warn(
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type               | Params
# -----------------------------------------------------
# 0 | model         | Sequential         | 55.1 K
# 1 | val_accuracy  | MulticlassAccuracy | 0
# 2 | test_accuracy | MulticlassAccuracy | 0
# -----------------------------------------------------
# 55.1 K    Trainable params
# 0         Non-trainable params
# 55.1 K    Total params
# 0.220     Total estimated model params size (MB)
# SLURM auto-requeueing enabled. Setting signal handlers.
# Sanity Checking DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# /users/PLS0129/ysu0053/.conda/envs/torch/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:442: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 40 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /users/PLS0129/ysu0053/.conda/envs/torch/lib/python3.10/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:442: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 40 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0: 100%|██████████| 196/196 [00:16<00:00, 11.55it/s, v_num=6407]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 60.10it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 27.17it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:02, 16.55it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:02, 15.64it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:02, 13.77it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:02, 13.68it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:02, 12.81it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:02, 12.51it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:02, 12.02it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:02, 11.89it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:02, 11.58it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:01<00:02, 11.51it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:01<00:02, 11.35it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:01<00:02, 11.48it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:01<00:02, 11.40it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:01<00:02, 11.28it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:01<00:01, 11.54it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:01<00:01, 11.38it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:01<00:01, 11.38it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:01<00:01, 11.25it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:01<00:01, 11.23it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:01<00:01, 11.37it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:02<00:01, 11.25it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:02<00:01, 11.25it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:02<00:01, 11.16it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:02<00:01, 11.14it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:02<00:01, 11.06it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:02<00:01, 11.05it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:02<00:01, 10.97it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:02<00:00, 10.97it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:02<00:00, 10.91it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:02<00:00, 10.89it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:03<00:00, 10.84it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:03<00:00, 10.85it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:03<00:00, 10.80it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:03<00:00, 10.80it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:03<00:00, 10.79it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:03<00:00, 10.79it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:03<00:00, 10.74it/s]
# Epoch 0: 100%|██████████| 196/196 [00:20<00:00,  9.46it/s, v_num=6407, val_loss=0.445, val_acc=0.883]
# Epoch 1: 100%|██████████| 196/196 [00:17<00:00, 11.46it/s, v_num=6407, val_loss=0.445, val_acc=0.883]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 76.33it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 33.34it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:02, 17.78it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:02, 15.31it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:02, 15.27it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:02, 13.70it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:02, 13.17it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:02, 12.49it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:02, 12.24it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:02, 12.48it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:02, 12.88it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:02, 12.60it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:01<00:02, 12.50it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:01<00:02, 12.66it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:01<00:02, 12.40it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:01<00:01, 12.33it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:01<00:01, 12.52it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:01<00:01, 12.77it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:01<00:01, 12.56it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:01<00:01, 12.50it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:01<00:01, 12.28it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:01<00:01, 12.23it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:01<00:01, 12.36it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:01<00:01, 12.21it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:02<00:01, 12.14it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:02<00:01, 12.00it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:02<00:01, 12.07it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:02<00:00, 12.01it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:02<00:00, 11.89it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:02<00:00, 11.95it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:02<00:00, 11.99it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:02<00:00, 11.94it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:02<00:00, 11.96it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:02<00:00, 11.88it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:02<00:00, 11.85it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:03<00:00, 11.92it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:03<00:00, 11.86it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:03<00:00, 11.83it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:03<00:00, 11.74it/s]
# Epoch 1: 100%|██████████| 196/196 [00:20<00:00,  9.56it/s, v_num=6407, val_loss=0.318, val_acc=0.907]
# Epoch 2: 100%|██████████| 196/196 [00:17<00:00, 11.26it/s, v_num=6407, val_loss=0.318, val_acc=0.907]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 49.75it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 24.05it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:01, 22.08it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:01, 21.53it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:01, 20.94it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:01, 20.75it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:01, 20.75it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:01, 20.61it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:01, 19.08it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:01, 17.47it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:01, 16.84it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:01, 15.83it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:01, 15.69it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:01, 15.28it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:01<00:01, 14.64it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:01<00:01, 14.32it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:01<00:01, 13.87it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:01<00:01, 13.65it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:01<00:01, 13.71it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:01<00:01, 13.43it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:01<00:01, 13.25it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:01<00:01, 13.33it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:01<00:01, 13.08it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:01<00:01, 13.21it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:01<00:01, 13.26it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:01<00:01, 13.13it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:02<00:01, 13.00it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:02<00:00, 12.95it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:02<00:00, 12.78it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:02<00:00, 12.73it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:02<00:00, 12.58it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:02<00:00, 12.52it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:02<00:00, 12.40it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:02<00:00, 12.35it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:02<00:00, 12.43it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:02<00:00, 12.54it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:02<00:00, 12.44it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:03<00:00, 12.46it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:03<00:00, 12.35it/s]
# Epoch 2: 100%|██████████| 196/196 [00:20<00:00,  9.49it/s, v_num=6407, val_loss=0.273, val_acc=0.918]
# Epoch 3: 100%|██████████| 196/196 [00:16<00:00, 11.69it/s, v_num=6407, val_loss=0.273, val_acc=0.918]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 59.10it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 26.16it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:02, 17.58it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:02, 16.98it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:02, 15.17it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:02, 14.20it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:02, 13.19it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:02, 12.96it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:02, 12.41it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:02, 12.22it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:02, 12.44it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:02, 12.17it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:01<00:02, 12.32it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:01<00:02, 12.21it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:01<00:02, 11.95it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:01<00:02, 11.87it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:01<00:01, 11.67it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:01<00:01, 11.62it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:01<00:01, 11.80it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:01<00:01, 11.99it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:01<00:01, 12.01it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:01<00:01, 12.16it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:01<00:01, 12.03it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:02<00:01, 11.97it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:02<00:01, 11.89it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:02<00:01, 11.86it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:02<00:01, 11.74it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:02<00:01, 11.70it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:02<00:00, 11.61it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:02<00:00, 11.58it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:02<00:00, 11.48it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:02<00:00, 11.47it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:02<00:00, 11.41it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:02<00:00, 11.39it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:03<00:00, 11.33it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:03<00:00, 11.33it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:03<00:00, 11.26it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:03<00:00, 11.25it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:03<00:00, 11.33it/s]
# Epoch 3: 100%|██████████| 196/196 [00:20<00:00,  9.65it/s, v_num=6407, val_loss=0.245, val_acc=0.926]
# Epoch 4: 100%|██████████| 196/196 [00:16<00:00, 11.71it/s, v_num=6407, val_loss=0.245, val_acc=0.926]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 145.39it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 33.12it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:01, 27.00it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:01, 26.00it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:01, 25.76it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:01, 23.53it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:01, 22.82it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:01, 20.03it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:01, 19.44it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:01, 17.58it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:01, 16.62it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:01, 15.59it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:00<00:01, 15.44it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:00<00:01, 14.98it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:01<00:01, 14.38it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:01<00:01, 14.36it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:01<00:01, 14.14it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:01<00:01, 13.79it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:01<00:01, 13.63it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:01<00:01, 13.52it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:01<00:01, 13.33it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:01<00:01, 13.27it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:01<00:01, 13.06it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:01<00:01, 12.94it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:01<00:01, 13.03it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:02<00:01, 12.89it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:02<00:01, 12.80it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:02<00:00, 12.64it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:02<00:00, 12.56it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:02<00:00, 12.47it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:02<00:00, 12.43it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:02<00:00, 12.33it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:02<00:00, 12.28it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:02<00:00, 12.36it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:02<00:00, 12.24it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:02<00:00, 12.21it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:03<00:00, 12.31it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:03<00:00, 12.30it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:03<00:00, 12.37it/s]
# Epoch 4: 100%|██████████| 196/196 [00:19<00:00,  9.81it/s, v_num=6407, val_loss=0.219, val_acc=0.934]
# Epoch 5: 100%|██████████| 196/196 [00:16<00:00, 11.94it/s, v_num=6407, val_loss=0.219, val_acc=0.934]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 66.75it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 24.24it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:02, 17.31it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:02, 16.79it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:02, 16.13it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:02, 15.28it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:02, 14.21it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:02, 13.67it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:02, 13.04it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:02, 12.78it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:02, 12.39it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:02, 12.23it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:01<00:02, 12.40it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:01<00:02, 12.72it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:01<00:02, 12.46it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:01<00:01, 12.38it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:01<00:01, 12.14it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:01<00:01, 12.09it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:01<00:01, 11.90it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:01<00:01, 11.98it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:01<00:01, 11.92it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:01<00:01, 11.80it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:01<00:01, 11.77it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:02<00:01, 11.69it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:02<00:01, 11.66it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:02<00:01, 11.56it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:02<00:01, 11.63it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:02<00:01, 11.62it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:02<00:00, 11.54it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:02<00:00, 11.51it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:02<00:00, 11.46it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:02<00:00, 11.54it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:02<00:00, 11.66it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:02<00:00, 11.65it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:03<00:00, 11.59it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:03<00:00, 11.58it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:03<00:00, 11.67it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:03<00:00, 11.79it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:03<00:00, 11.72it/s]
# Epoch 5: 100%|██████████| 196/196 [00:19<00:00,  9.87it/s, v_num=6407, val_loss=0.200, val_acc=0.939]
# Epoch 6: 100%|██████████| 196/196 [00:17<00:00, 11.47it/s, v_num=6407, val_loss=0.200, val_acc=0.939]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 69.19it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 27.97it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:02, 16.93it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:02, 14.79it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:02, 13.42it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:02, 13.56it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:02, 13.18it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:02, 12.51it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:02, 12.42it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:02, 12.01it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:02, 12.17it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:02, 12.05it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:01<00:02, 11.77it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:01<00:02, 11.75it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:01<00:02, 11.99it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:01<00:02, 11.76it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:01<00:01, 11.89it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:01<00:01, 11.82it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:01<00:01, 11.98it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:01<00:01, 12.22it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:01<00:01, 12.07it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:01<00:01, 12.05it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:01<00:01, 11.89it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:02<00:01, 11.95it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:02<00:01, 11.90it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:02<00:01, 11.78it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:02<00:01, 11.76it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:02<00:01, 11.65it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:02<00:00, 11.62it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:02<00:00, 11.52it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:02<00:00, 11.49it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:02<00:00, 11.40it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:02<00:00, 11.38it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:03<00:00, 11.31it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:03<00:00, 11.29it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:03<00:00, 11.26it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:03<00:00, 11.26it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:03<00:00, 11.21it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:03<00:00, 11.21it/s]
# Epoch 6: 100%|██████████| 196/196 [00:20<00:00,  9.48it/s, v_num=6407, val_loss=0.184, val_acc=0.943]
# Epoch 7: 100%|██████████| 196/196 [00:16<00:00, 11.74it/s, v_num=6407, val_loss=0.184, val_acc=0.943]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 88.58it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 35.19it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:01, 24.01it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:01, 18.33it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:02, 15.92it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:02, 14.75it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:02, 13.81it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:02, 13.51it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:02, 13.09it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:02, 12.89it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:02, 12.58it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:02, 12.53it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:01<00:02, 12.17it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:01<00:02, 12.10it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:01<00:02, 11.85it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:01<00:02, 11.81it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:01<00:01, 11.99it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:01<00:01, 11.87it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:01<00:01, 11.81it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:01<00:01, 11.71it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:01<00:01, 11.68it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:01<00:01, 11.56it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:01<00:01, 11.53it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:02<00:01, 11.43it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:02<00:01, 11.52it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:02<00:01, 11.51it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:02<00:01, 11.41it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:02<00:01, 11.39it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:02<00:00, 11.32it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:02<00:00, 11.30it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:02<00:00, 11.22it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:02<00:00, 11.21it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:02<00:00, 11.29it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:03<00:00, 11.28it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:03<00:00, 11.26it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:03<00:00, 11.20it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:03<00:00, 11.26it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:03<00:00, 11.26it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:03<00:00, 11.22it/s]
# Epoch 7: 100%|██████████| 196/196 [00:20<00:00,  9.68it/s, v_num=6407, val_loss=0.171, val_acc=0.948]
# Epoch 8: 100%|██████████| 196/196 [00:17<00:00, 11.35it/s, v_num=6407, val_loss=0.171, val_acc=0.948]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 82.29it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 21.89it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:01, 21.34it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:02, 17.34it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:02, 14.48it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:02, 13.42it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:02, 13.08it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:02, 12.45it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:02, 12.61it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:02, 12.46it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:02, 12.15it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:00<00:02, 12.04it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:01<00:02, 11.82it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:01<00:02, 11.80it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:01<00:02, 12.01it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:01<00:02, 11.79it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:01<00:01, 11.78it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:01<00:01, 11.60it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:01<00:01, 11.56it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:01<00:01, 11.72it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:01<00:01, 11.60it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:01<00:01, 11.57it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:02<00:01, 11.44it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:02<00:01, 11.49it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:02<00:01, 11.65it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:02<00:01, 11.61it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:02<00:01, 11.58it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:02<00:01, 11.47it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:02<00:00, 11.45it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:02<00:00, 11.36it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:02<00:00, 11.34it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:02<00:00, 11.44it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:02<00:00, 11.39it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:02<00:00, 11.39it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:03<00:00, 11.31it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:03<00:00, 11.37it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:03<00:00, 11.37it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:03<00:00, 11.30it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:03<00:00, 11.32it/s]
# Epoch 8: 100%|██████████| 196/196 [00:20<00:00,  9.42it/s, v_num=6407, val_loss=0.157, val_acc=0.952]
# Epoch 9: 100%|██████████| 196/196 [00:17<00:00, 11.23it/s, v_num=6407, val_loss=0.157, val_acc=0.952]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/40 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▎         | 1/40 [00:00<00:00, 76.74it/s]
# Validation DataLoader 0:   5%|▌         | 2/40 [00:00<00:01, 22.51it/s]
# Validation DataLoader 0:   8%|▊         | 3/40 [00:00<00:02, 15.91it/s]
# Validation DataLoader 0:  10%|█         | 4/40 [00:00<00:02, 14.42it/s]
# Validation DataLoader 0:  12%|█▎        | 5/40 [00:00<00:02, 13.15it/s]
# Validation DataLoader 0:  15%|█▌        | 6/40 [00:00<00:02, 12.70it/s]
# Validation DataLoader 0:  18%|█▊        | 7/40 [00:00<00:02, 12.05it/s]
# Validation DataLoader 0:  20%|██        | 8/40 [00:00<00:02, 11.86it/s]
# Validation DataLoader 0:  22%|██▎       | 9/40 [00:00<00:02, 11.79it/s]
# Validation DataLoader 0:  25%|██▌       | 10/40 [00:00<00:02, 11.71it/s]
# Validation DataLoader 0:  28%|██▊       | 11/40 [00:00<00:02, 11.43it/s]
# Validation DataLoader 0:  30%|███       | 12/40 [00:01<00:02, 11.40it/s]
# Validation DataLoader 0:  32%|███▎      | 13/40 [00:01<00:02, 11.20it/s]
# Validation DataLoader 0:  35%|███▌      | 14/40 [00:01<00:02, 11.17it/s]
# Validation DataLoader 0:  38%|███▊      | 15/40 [00:01<00:02, 11.02it/s]
# Validation DataLoader 0:  40%|████      | 16/40 [00:01<00:02, 11.18it/s]
# Validation DataLoader 0:  42%|████▎     | 17/40 [00:01<00:02, 11.28it/s]
# Validation DataLoader 0:  45%|████▌     | 18/40 [00:01<00:01, 11.14it/s]
# Validation DataLoader 0:  48%|████▊     | 19/40 [00:01<00:01, 11.14it/s]
# Validation DataLoader 0:  50%|█████     | 20/40 [00:01<00:01, 11.06it/s]
# Validation DataLoader 0:  52%|█████▎    | 21/40 [00:01<00:01, 11.14it/s]
# Validation DataLoader 0:  55%|█████▌    | 22/40 [00:01<00:01, 11.14it/s]
# Validation DataLoader 0:  57%|█████▊    | 23/40 [00:02<00:01, 11.18it/s]
# Validation DataLoader 0:  60%|██████    | 24/40 [00:02<00:01, 11.17it/s]
# Validation DataLoader 0:  62%|██████▎   | 25/40 [00:02<00:01, 11.15it/s]
# Validation DataLoader 0:  65%|██████▌   | 26/40 [00:02<00:01, 11.26it/s]
# Validation DataLoader 0:  68%|██████▊   | 27/40 [00:02<00:01, 11.26it/s]
# Validation DataLoader 0:  70%|███████   | 28/40 [00:02<00:01, 11.20it/s]
# Validation DataLoader 0:  72%|███████▎  | 29/40 [00:02<00:00, 11.26it/s]
# Validation DataLoader 0:  75%|███████▌  | 30/40 [00:02<00:00, 11.26it/s]
# Validation DataLoader 0:  78%|███████▊  | 31/40 [00:02<00:00, 11.27it/s]
# Validation DataLoader 0:  80%|████████  | 32/40 [00:02<00:00, 11.26it/s]
# Validation DataLoader 0:  82%|████████▎ | 33/40 [00:02<00:00, 11.21it/s]
# Validation DataLoader 0:  85%|████████▌ | 34/40 [00:03<00:00, 11.19it/s]
# Validation DataLoader 0:  88%|████████▊ | 35/40 [00:03<00:00, 11.28it/s]
# Validation DataLoader 0:  90%|█████████ | 36/40 [00:03<00:00, 11.28it/s]
# Validation DataLoader 0:  92%|█████████▎| 37/40 [00:03<00:00, 11.28it/s]
# Validation DataLoader 0:  95%|█████████▌| 38/40 [00:03<00:00, 11.37it/s]
# Validation DataLoader 0:  98%|█████████▊| 39/40 [00:03<00:00, 11.48it/s]
# Epoch 9: 100%|██████████| 196/196 [00:20<00:00,  9.35it/s, v_num=6407, val_loss=0.148, val_acc=0.955]
# Epoch 10:  99%|█████████▉| 195/196 [00:16<00:00, 11.50it/s, v_num=6407, val_loss=0.148, val_acc=0.955]
